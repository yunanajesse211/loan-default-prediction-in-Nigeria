# %% [markdown]
# ## Library Importation and Data Importation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report, precision_score, recall_score,f1_score,roc_auc_score
import warnings
warnings.filterwarnings('ignore')

# %%
# from google.colab import files
# files.upload()

# %%
df1 = pd.read_csv("data/train3.csv")
df2= pd.read_csv("data/train2.xls")
df3 = pd.read_csv("data/train1.xls")

# %%
df4=pd.merge(df1,df2, how='inner',on='customerid')

# %%
df=pd.merge(df4,df3, how='inner',on='customerid')
df4
# Out:
#                              customerid  systemloanid_x  loannumber_x  \
# 0      8a2a81a74ce8c05d014cfb32a0da1049       301682320             2
# 1      8a2a81a74ce8c05d014cfb32a0da1049       301883808             9
# 2      8a2a81a74ce8c05d014cfb32a0da1049       301831714             8
# 3      8a2a81a74ce8c05d014cfb32a0da1049       301923941            10
# 4      8a2a81a74ce8c05d014cfb32a0da1049       301954468            11
# ...                                 ...             ...           ...
# 18178  8a858f305c8dd672015c92b0711a3333       301941335             1
# 18179  8a858fe7568ed7420156920bff565cc7       301955570             1
# 18180  8a858f6459b6456d0159b69978f22bed       301796830             1
# 18181  8a858fad5ccb633e015ccbe337372ab3       301946936             1
# 18182  8a858f0656b7820c0156c92ca3ba436f       301697691             1
#
#                    approveddate_x              creationdate_x  loanamount_x  \
# 0      2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000       10000.0
# 1      2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000       10000.0
# 2      2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000       20000.0
# 3      2017-06-01 13:34:30.000000  2017-06-01 12:34:21.000000       20000.0
# 4      2017-06-28 10:58:34.000000  2017-06-28 09:58:25.000000       20000.0
# ...                           ...                         ...           ...
# 18178  2017-06-16 18:16:37.000000  2017-06-16 17:15:29.000000       10000.0
# 18179  2017-06-29 01:25:57.000000  2017-06-29 00:25:48.000000       10000.0
# 18180  2017-01-19 14:00:16.000000  2017-01-19 13:00:02.000000       10000.0
# 18181  2017-06-21 20:19:29.000000  2017-06-21 19:18:21.000000       10000.0
# 18182  2016-08-27 20:03:45.000000  2016-08-27 19:03:34.000000       10000.0
#
#        totaldue_x  termdays_x                  closeddate  \
# 0         13000.0          30  2016-09-01 16:06:48.000000
# 1         13000.0          30  2017-05-28 14:44:49.000000
# 2         23800.0          30  2017-04-26 22:18:56.000000
# 3         24500.0          30  2017-06-25 15:24:06.000000
# 4         24500.0          30  2017-07-25 08:14:36.000000
# ...           ...         ...                         ...
# 18178     11500.0          15  2017-06-26 14:02:03.000000
# 18179     11500.0          15  2017-07-05 14:31:17.000000
# 18180     11500.0          15  2017-02-15 09:06:34.000000
# 18181     13000.0          30  2017-07-07 17:08:47.000000
# 18182     13000.0          30  2016-10-15 10:17:54.000000
#
#                            referredby_x  ...             firstrepaiddate  \
# 0                                   NaN  ...  2016-09-01 15:51:43.000000
# 1                                   NaN  ...  2017-05-26 00:00:00.000000
# 2                                   NaN  ...  2017-04-26 22:03:47.000000
# 3                                   NaN  ...  2017-06-25 15:13:56.000000
# 4                                   NaN  ...  2017-07-25 08:04:27.000000
# ...                                 ...  ...                         ...
# 18178                               NaN  ...  2017-06-26 13:51:54.000000
# 18179                               NaN  ...  2017-07-05 14:21:08.000000
# 18180                               NaN  ...  2017-02-15 08:51:25.000000
# 18181  8a858eaa55a0b8ae0155ad2cab5e49cc  ...  2017-07-07 16:58:38.000000
# 18182                               NaN  ...  2016-10-15 10:02:45.000000
#
#       systemloanid_y  loannumber_y              approveddate_y  \
# 0          301994762            12  2017-07-25 08:22:56.000000
# 1          301994762            12  2017-07-25 08:22:56.000000
# 2          301994762            12  2017-07-25 08:22:56.000000
# 3          301994762            12  2017-07-25 08:22:56.000000
# 4          301994762            12  2017-07-25 08:22:56.000000
# ...              ...           ...                         ...
# 18178      301978946             2  2017-07-15 10:42:38.000000
# 18179      301976025             2  2017-07-13 13:07:40.000000
# 18180      301969032             2  2017-07-08 10:12:52.000000
# 18181      301977456             2  2017-07-14 12:00:54.000000
# 18182      301996908             2  2017-07-26 12:48:14.000000
#
#                    creationdate_y loanamount_y  totaldue_y  termdays_y  \
# 0      2017-07-25 07:22:47.000000      30000.0     34500.0          30
# 1      2017-07-25 07:22:47.000000      30000.0     34500.0          30
# 2      2017-07-25 07:22:47.000000      30000.0     34500.0          30
# 3      2017-07-25 07:22:47.000000      30000.0     34500.0          30
# 4      2017-07-25 07:22:47.000000      30000.0     34500.0          30
# ...                           ...          ...         ...         ...
# 18178  2017-07-15 09:42:24.000000      10000.0     11500.0          15
# 18179  2017-07-13 12:07:32.000000      10000.0     13000.0          30
# 18180  2017-07-08 09:12:37.000000      10000.0     13000.0          30
# 18181  2017-07-14 11:00:48.000000      10000.0     13000.0          30
# 18182  2017-07-26 11:46:58.000000      10000.0     13000.0          30
#
#                            referredby_y good_bad_flag
# 0                                   NaN          Good
# 1                                   NaN          Good
# 2                                   NaN          Good
# 3                                   NaN          Good
# 4                                   NaN          Good
# ...                                 ...           ...
# 18178                               NaN          Good
# 18179                               NaN          Good
# 18180                               NaN          Good
# 18181  8a858eaa55a0b8ae0155ad2cab5e49cc          Good
# 18182                               NaN           Bad
#
# [18183 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13693 entries, 0 to 13692
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customerid                  13693 non-null  object
#  1   systemloanid_x              13693 non-null  int64
#  2   loannumber_x                13693 non-null  int64
#  3   approveddate_x              13693 non-null  object
#  4   creationdate_x              13693 non-null  object
#  5   loanamount_x                13693 non-null  float64
#  6   totaldue_x                  13693 non-null  float64
#  7   termdays_x                  13693 non-null  int64
#  8   closeddate                  13693 non-null  object
#  9   referredby_x                802 non-null    object
#  10  firstduedate                13693 non-null  object
#  11  firstrepaiddate             13693 non-null  object
#  12  systemloanid_y              13693 non-null  int64
#  13  loannumber_y                13693 non-null  int64
#  14  approveddate_y              13693 non-null  object
#  15  creationdate_y              13693 non-null  object
#  16  loanamount_y                13693 non-null  float64
#  17  totaldue_y                  13693 non-null  float64
#  18  termdays_y                  13693 non-null  int64
#  19  referredby_y                802 non-null    object
#  20  good_bad_flag               13693 non-null  object
#  21  birthdate                   13693 non-null  object
#  22  bank_account_type           13693 non-null  object
#  23  longitude_gps               13693 non-null  float64
#  24  latitude_gps                13693 non-null  float64
#  25  bank_name_clients           13693 non-null  object
#  26  bank_branch_clients         104 non-null    object
#  27  employment_status_clients   12330 non-null  object
#  28  level_of_education_clients  3464 non-null   object
# dtypes: float64(6), int64(6), object(17)
# memory usage: 3.1+ MB

# %%
# df=df.dropna()
# df

# %%
df.describe()
# Out:
#        systemloanid_x  loannumber_x  loanamount_x    totaldue_x    termdays_x  \
# count    1.369300e+04  13693.000000  13693.000000  13693.000000  13693.000000
# mean     3.018395e+08      4.200760  16566.347769  19646.612269     26.742131
# std      9.304690e+04      3.269552   9375.687619  10512.238823     10.997624
# min      3.016001e+08      1.000000   3000.000000   3900.000000     15.000000
# 25%      3.017767e+08      2.000000  10000.000000  11500.000000     15.000000
# 50%      3.018545e+08      3.000000  10000.000000  13000.000000     30.000000
# 75%      3.019193e+08      6.000000  20000.000000  24500.000000     30.000000
# max      3.020003e+08     26.000000  60000.000000  68100.000000     90.000000
#
#        systemloanid_y  loannumber_y  loanamount_y    totaldue_y    termdays_y  \
# count    1.369300e+04  13693.000000  13693.000000  13693.000000  13693.000000
# mean     3.019801e+08      8.401081  25688.673045  29812.666494     33.233769
# std      1.343531e+04      4.318780  12625.374212  13772.770273     14.440482
# min      3.019585e+08      2.000000  10000.000000  10000.000000     15.000000
# 25%      3.019678e+08      5.000000  10000.000000  13000.000000     30.000000
# 50%      3.019787e+08      8.000000  30000.000000  33000.000000     30.000000
# 75%      3.019929e+08     11.000000  40000.000000  44000.000000     30.000000
# max      3.020040e+08     27.000000  60000.000000  68100.000000     90.000000
#
#        longitude_gps  latitude_gps
# count   13693.000000  13693.000000
# mean        4.482207      7.291442
# std         8.639590      3.436232
# min      -118.247009    -33.868818
# 25%         3.354793      6.471885
# 50%         3.576022      6.617633
# 75%         6.364658      7.421333
# max       151.209290     71.228069

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                              customerid  systemloanid_x  loannumber_x  \
# 0      8a2a81a74ce8c05d014cfb32a0da1049       301682320             2
# 1      8a2a81a74ce8c05d014cfb32a0da1049       301883808             9
# 2      8a2a81a74ce8c05d014cfb32a0da1049       301831714             8
# 3      8a2a81a74ce8c05d014cfb32a0da1049       301923941            10
# 4      8a2a81a74ce8c05d014cfb32a0da1049       301954468            11
# ...                                 ...             ...           ...
# 13688  8a858ec65cf4605b015cf4ed88665334       301980231             1
# 13689  8a858eaf5b617c94015b6194555e10a2       301938001             1
# 13690  8a858f305c8dd672015c92b0711a3333       301941335             1
# 13691  8a858fe7568ed7420156920bff565cc7       301955570             1
# 13692  8a858f6459b6456d0159b69978f22bed       301796830             1
#
#                    approveddate_x              creationdate_x  loanamount_x  \
# 0      2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000       10000.0
# 1      2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000       10000.0
# 2      2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000       20000.0
# 3      2017-06-01 13:34:30.000000  2017-06-01 12:34:21.000000       20000.0
# 4      2017-06-28 10:58:34.000000  2017-06-28 09:58:25.000000       20000.0
# ...                           ...                         ...           ...
# 13688  2017-07-16 12:01:31.000000  2017-07-16 11:00:13.000000       10000.0
# 13689  2017-06-14 06:50:41.000000  2017-06-14 05:49:34.000000       10000.0
# 13690  2017-06-16 18:16:37.000000  2017-06-16 17:15:29.000000       10000.0
# 13691  2017-06-29 01:25:57.000000  2017-06-29 00:25:48.000000       10000.0
# 13692  2017-01-19 14:00:16.000000  2017-01-19 13:00:02.000000       10000.0
#
#        totaldue_x  termdays_x                  closeddate  \
# 0         13000.0          30  2016-09-01 16:06:48.000000
# 1         13000.0          30  2017-05-28 14:44:49.000000
# 2         23800.0          30  2017-04-26 22:18:56.000000
# 3         24500.0          30  2017-06-25 15:24:06.000000
# 4         24500.0          30  2017-07-25 08:14:36.000000
# ...           ...         ...                         ...
# 13688     11500.0          15  2017-07-18 16:33:55.000000
# 13689     13000.0          30  2017-07-11 14:26:40.000000
# 13690     11500.0          15  2017-06-26 14:02:03.000000
# 13691     11500.0          15  2017-07-05 14:31:17.000000
# 13692     11500.0          15  2017-02-15 09:06:34.000000
#
#                            referredby_x  ...  \
# 0                                   NaN  ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4                                   NaN  ...
# ...                                 ...  ...
# 13688                               NaN  ...
# 13689  8a858ff15b5d3f84015b5d509bd61cae  ...
# 13690                               NaN  ...
# 13691                               NaN  ...
# 13692                               NaN  ...
#
#                            referredby_y good_bad_flag  \
# 0                                   NaN          Good
# 1                                   NaN          Good
# 2                                   NaN          Good
# 3                                   NaN          Good
# 4                                   NaN          Good
# ...                                 ...           ...
# 13688                               NaN          Good
# 13689  8a858ff15b5d3f84015b5d509bd61cae          Good
# 13690                               NaN          Good
# 13691                               NaN          Good
# 13692                               NaN          Good
#
#                         birthdate  bank_account_type longitude_gps  \
# 0      1972-01-15 00:00:00.000000              Other      3.432010
# 1      1972-01-15 00:00:00.000000              Other      3.432010
# 2      1972-01-15 00:00:00.000000              Other      3.432010
# 3      1972-01-15 00:00:00.000000              Other      3.432010
# 4      1972-01-15 00:00:00.000000              Other      3.432010
# ...                           ...                ...           ...
# 13688  1986-02-20 00:00:00.000000            Savings      5.252457
# 13689  1979-04-18 00:00:00.000000            Savings      7.478858
# 13690  1989-11-19 00:00:00.000000            Savings      3.381677
# 13691  1980-11-12 00:00:00.000000            Savings      6.979660
# 13692  1989-10-24 00:00:00.000000            Savings      7.530892
#
#       latitude_gps  bank_name_clients  bank_branch_clients  \
# 0         6.433055       Diamond Bank                  NaN
# 1         6.433055       Diamond Bank                  NaN
# 2         6.433055       Diamond Bank                  NaN
# 3         6.433055       Diamond Bank                  NaN
# 4         6.433055       Diamond Bank                  NaN
# ...            ...                ...                  ...
# 13688    12.991440                UBA                  NaN
# 13689     9.055714               FCMB                  NaN
# 13690     6.455923        Zenith Bank                  NaN
# 13691     4.879515        Access Bank                  NaN
# 13692     9.042928            EcoBank                  NaN
#
#        employment_status_clients level_of_education_clients
# 0                      Permanent              Post-Graduate
# 1                      Permanent              Post-Graduate
# 2                      Permanent              Post-Graduate
# 3                      Permanent              Post-Graduate
# 4                      Permanent              Post-Graduate
# ...                          ...                        ...
# 13688                  Permanent                        NaN
# 13689                  Permanent                        NaN
# 13690                  Permanent                        NaN
# 13691                 Unemployed                   Graduate
# 13692                  Permanent                        NaN
#
# [13673 rows x 29 columns]

# %%
df = df.drop(["referredby_x","referredby_y",'bank_branch_clients','level_of_education_clients'], axis = 1)

# %%
data=df
data
# Out:
#                              customerid  systemloanid_x  loannumber_x  \
# 0      8a2a81a74ce8c05d014cfb32a0da1049       301682320             2
# 1      8a2a81a74ce8c05d014cfb32a0da1049       301883808             9
# 2      8a2a81a74ce8c05d014cfb32a0da1049       301831714             8
# 3      8a2a81a74ce8c05d014cfb32a0da1049       301923941            10
# 4      8a2a81a74ce8c05d014cfb32a0da1049       301954468            11
# ...                                 ...             ...           ...
# 13688  8a858ec65cf4605b015cf4ed88665334       301980231             1
# 13689  8a858eaf5b617c94015b6194555e10a2       301938001             1
# 13690  8a858f305c8dd672015c92b0711a3333       301941335             1
# 13691  8a858fe7568ed7420156920bff565cc7       301955570             1
# 13692  8a858f6459b6456d0159b69978f22bed       301796830             1
#
#                    approveddate_x              creationdate_x  loanamount_x  \
# 0      2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000       10000.0
# 1      2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000       10000.0
# 2      2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000       20000.0
# 3      2017-06-01 13:34:30.000000  2017-06-01 12:34:21.000000       20000.0
# 4      2017-06-28 10:58:34.000000  2017-06-28 09:58:25.000000       20000.0
# ...                           ...                         ...           ...
# 13688  2017-07-16 12:01:31.000000  2017-07-16 11:00:13.000000       10000.0
# 13689  2017-06-14 06:50:41.000000  2017-06-14 05:49:34.000000       10000.0
# 13690  2017-06-16 18:16:37.000000  2017-06-16 17:15:29.000000       10000.0
# 13691  2017-06-29 01:25:57.000000  2017-06-29 00:25:48.000000       10000.0
# 13692  2017-01-19 14:00:16.000000  2017-01-19 13:00:02.000000       10000.0
#
#        totaldue_x  termdays_x                  closeddate  \
# 0         13000.0          30  2016-09-01 16:06:48.000000
# 1         13000.0          30  2017-05-28 14:44:49.000000
# 2         23800.0          30  2017-04-26 22:18:56.000000
# 3         24500.0          30  2017-06-25 15:24:06.000000
# 4         24500.0          30  2017-07-25 08:14:36.000000
# ...           ...         ...                         ...
# 13688     11500.0          15  2017-07-18 16:33:55.000000
# 13689     13000.0          30  2017-07-11 14:26:40.000000
# 13690     11500.0          15  2017-06-26 14:02:03.000000
# 13691     11500.0          15  2017-07-05 14:31:17.000000
# 13692     11500.0          15  2017-02-15 09:06:34.000000
#
#                      firstduedate  ... loanamount_y  totaldue_y  termdays_y  \
# 0      2016-09-14 00:00:00.000000  ...      30000.0     34500.0          30
# 1      2017-05-30 00:00:00.000000  ...      30000.0     34500.0          30
# 2      2017-04-04 00:00:00.000000  ...      30000.0     34500.0          30
# 3      2017-07-03 00:00:00.000000  ...      30000.0     34500.0          30
# 4      2017-07-31 00:00:00.000000  ...      30000.0     34500.0          30
# ...                           ...  ...          ...         ...         ...
# 13688  2017-07-31 00:00:00.000000  ...      10000.0     11500.0          15
# 13689  2017-07-14 00:00:00.000000  ...      10000.0     13000.0          30
# 13690  2017-07-03 00:00:00.000000  ...      10000.0     11500.0          15
# 13691  2017-07-14 00:00:00.000000  ...      10000.0     13000.0          30
# 13692  2017-02-03 00:00:00.000000  ...      10000.0     13000.0          30
#
#       good_bad_flag                   birthdate  bank_account_type  \
# 0              Good  1972-01-15 00:00:00.000000              Other
# 1              Good  1972-01-15 00:00:00.000000              Other
# 2              Good  1972-01-15 00:00:00.000000              Other
# 3              Good  1972-01-15 00:00:00.000000              Other
# 4              Good  1972-01-15 00:00:00.000000              Other
# ...             ...                         ...                ...
# 13688          Good  1986-02-20 00:00:00.000000            Savings
# 13689          Good  1979-04-18 00:00:00.000000            Savings
# 13690          Good  1989-11-19 00:00:00.000000            Savings
# 13691          Good  1980-11-12 00:00:00.000000            Savings
# 13692          Good  1989-10-24 00:00:00.000000            Savings
#
#        longitude_gps  latitude_gps bank_name_clients employment_status_clients
# 0           3.432010      6.433055      Diamond Bank                 Permanent
# 1           3.432010      6.433055      Diamond Bank                 Permanent
# 2           3.432010      6.433055      Diamond Bank                 Permanent
# 3           3.432010      6.433055      Diamond Bank                 Permanent
# 4           3.432010      6.433055      Diamond Bank                 Permanent
# ...              ...           ...               ...                       ...
# 13688       5.252457     12.991440               UBA                 Permanent
# 13689       7.478858      9.055714              FCMB                 Permanent
# 13690       3.381677      6.455923       Zenith Bank                 Permanent
# 13691       6.979660      4.879515       Access Bank                Unemployed
# 13692       7.530892      9.042928           EcoBank                 Permanent
#
# [13673 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13673 entries, 0 to 13692
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerid                 13673 non-null  object
#  1   systemloanid_x             13673 non-null  int64
#  2   loannumber_x               13673 non-null  int64
#  3   approveddate_x             13673 non-null  object
#  4   creationdate_x             13673 non-null  object
#  5   loanamount_x               13673 non-null  float64
#  6   totaldue_x                 13673 non-null  float64
#  7   termdays_x                 13673 non-null  int64
#  8   closeddate                 13673 non-null  object
#  9   firstduedate               13673 non-null  object
#  10  firstrepaiddate            13673 non-null  object
#  11  systemloanid_y             13673 non-null  int64
#  12  loannumber_y               13673 non-null  int64
#  13  approveddate_y             13673 non-null  object
#  14  creationdate_y             13673 non-null  object
#  15  loanamount_y               13673 non-null  float64
#  16  totaldue_y                 13673 non-null  float64
#  17  termdays_y                 13673 non-null  int64
#  18  good_bad_flag              13673 non-null  object
#  19  birthdate                  13673 non-null  object
#  20  bank_account_type          13673 non-null  object
#  21  longitude_gps              13673 non-null  float64
#  22  latitude_gps               13673 non-null  float64
#  23  bank_name_clients          13673 non-null  object
#  24  employment_status_clients  12310 non-null  object
# dtypes: float64(6), int64(6), object(13)
# memory usage: 2.7+ MB

# %%
df=df.dropna()
df
# Out:
#                              customerid  systemloanid_x  loannumber_x  \
# 0      8a2a81a74ce8c05d014cfb32a0da1049       301682320             2
# 1      8a2a81a74ce8c05d014cfb32a0da1049       301883808             9
# 2      8a2a81a74ce8c05d014cfb32a0da1049       301831714             8
# 3      8a2a81a74ce8c05d014cfb32a0da1049       301923941            10
# 4      8a2a81a74ce8c05d014cfb32a0da1049       301954468            11
# ...                                 ...             ...           ...
# 13688  8a858ec65cf4605b015cf4ed88665334       301980231             1
# 13689  8a858eaf5b617c94015b6194555e10a2       301938001             1
# 13690  8a858f305c8dd672015c92b0711a3333       301941335             1
# 13691  8a858fe7568ed7420156920bff565cc7       301955570             1
# 13692  8a858f6459b6456d0159b69978f22bed       301796830             1
#
#                    approveddate_x              creationdate_x  loanamount_x  \
# 0      2016-08-15 18:22:40.000000  2016-08-15 17:22:32.000000       10000.0
# 1      2017-04-28 18:39:07.000000  2017-04-28 17:38:53.000000       10000.0
# 2      2017-03-05 10:56:25.000000  2017-03-05 09:56:19.000000       20000.0
# 3      2017-06-01 13:34:30.000000  2017-06-01 12:34:21.000000       20000.0
# 4      2017-06-28 10:58:34.000000  2017-06-28 09:58:25.000000       20000.0
# ...                           ...                         ...           ...
# 13688  2017-07-16 12:01:31.000000  2017-07-16 11:00:13.000000       10000.0
# 13689  2017-06-14 06:50:41.000000  2017-06-14 05:49:34.000000       10000.0
# 13690  2017-06-16 18:16:37.000000  2017-06-16 17:15:29.000000       10000.0
# 13691  2017-06-29 01:25:57.000000  2017-06-29 00:25:48.000000       10000.0
# 13692  2017-01-19 14:00:16.000000  2017-01-19 13:00:02.000000       10000.0
#
#        totaldue_x  termdays_x                  closeddate  \
# 0         13000.0          30  2016-09-01 16:06:48.000000
# 1         13000.0          30  2017-05-28 14:44:49.000000
# 2         23800.0          30  2017-04-26 22:18:56.000000
# 3         24500.0          30  2017-06-25 15:24:06.000000
# 4         24500.0          30  2017-07-25 08:14:36.000000
# ...           ...         ...                         ...
# 13688     11500.0          15  2017-07-18 16:33:55.000000
# 13689     13000.0          30  2017-07-11 14:26:40.000000
# 13690     11500.0          15  2017-06-26 14:02:03.000000
# 13691     11500.0          15  2017-07-05 14:31:17.000000
# 13692     11500.0          15  2017-02-15 09:06:34.000000
#
#                      firstduedate  ... loanamount_y  totaldue_y  termdays_y  \
# 0      2016-09-14 00:00:00.000000  ...      30000.0     34500.0          30
# 1      2017-05-30 00:00:00.000000  ...      30000.0     34500.0          30
# 2      2017-04-04 00:00:00.000000  ...      30000.0     34500.0          30
# 3      2017-07-03 00:00:00.000000  ...      30000.0     34500.0          30
# 4      2017-07-31 00:00:00.000000  ...      30000.0     34500.0          30
# ...                           ...  ...          ...         ...         ...
# 13688  2017-07-31 00:00:00.000000  ...      10000.0     11500.0          15
# 13689  2017-07-14 00:00:00.000000  ...      10000.0     13000.0          30
# 13690  2017-07-03 00:00:00.000000  ...      10000.0     11500.0          15
# 13691  2017-07-14 00:00:00.000000  ...      10000.0     13000.0          30
# 13692  2017-02-03 00:00:00.000000  ...      10000.0     13000.0          30
#
#       good_bad_flag                   birthdate  bank_account_type  \
# 0              Good  1972-01-15 00:00:00.000000              Other
# 1              Good  1972-01-15 00:00:00.000000              Other
# 2              Good  1972-01-15 00:00:00.000000              Other
# 3              Good  1972-01-15 00:00:00.000000              Other
# 4              Good  1972-01-15 00:00:00.000000              Other
# ...             ...                         ...                ...
# 13688          Good  1986-02-20 00:00:00.000000            Savings
# 13689          Good  1979-04-18 00:00:00.000000            Savings
# 13690          Good  1989-11-19 00:00:00.000000            Savings
# 13691          Good  1980-11-12 00:00:00.000000            Savings
# 13692          Good  1989-10-24 00:00:00.000000            Savings
#
#        longitude_gps  latitude_gps bank_name_clients employment_status_clients
# 0           3.432010      6.433055      Diamond Bank                 Permanent
# 1           3.432010      6.433055      Diamond Bank                 Permanent
# 2           3.432010      6.433055      Diamond Bank                 Permanent
# 3           3.432010      6.433055      Diamond Bank                 Permanent
# 4           3.432010      6.433055      Diamond Bank                 Permanent
# ...              ...           ...               ...                       ...
# 13688       5.252457     12.991440               UBA                 Permanent
# 13689       7.478858      9.055714              FCMB                 Permanent
# 13690       3.381677      6.455923       Zenith Bank                 Permanent
# 13691       6.979660      4.879515       Access Bank                Unemployed
# 13692       7.530892      9.042928           EcoBank                 Permanent
#
# [12310 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12310 entries, 0 to 13692
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerid                 12310 non-null  object
#  1   systemloanid_x             12310 non-null  int64
#  2   loannumber_x               12310 non-null  int64
#  3   approveddate_x             12310 non-null  object
#  4   creationdate_x             12310 non-null  object
#  5   loanamount_x               12310 non-null  float64
#  6   totaldue_x                 12310 non-null  float64
#  7   termdays_x                 12310 non-null  int64
#  8   closeddate                 12310 non-null  object
#  9   firstduedate               12310 non-null  object
#  10  firstrepaiddate            12310 non-null  object
#  11  systemloanid_y             12310 non-null  int64
#  12  loannumber_y               12310 non-null  int64
#  13  approveddate_y             12310 non-null  object
#  14  creationdate_y             12310 non-null  object
#  15  loanamount_y               12310 non-null  float64
#  16  totaldue_y                 12310 non-null  float64
#  17  termdays_y                 12310 non-null  int64
#  18  good_bad_flag              12310 non-null  object
#  19  birthdate                  12310 non-null  object
#  20  bank_account_type          12310 non-null  object
#  21  longitude_gps              12310 non-null  float64
#  22  latitude_gps               12310 non-null  float64
#  23  bank_name_clients          12310 non-null  object
#  24  employment_status_clients  12310 non-null  object
# dtypes: float64(6), int64(6), object(13)
# memory usage: 2.4+ MB

# %%
df = df.drop(["customerid","systemloanid_x",'approveddate_x','approveddate_y','creationdate_y','creationdate_x','closeddate','firstduedate','firstrepaiddate','systemloanid_y'], axis = 1)
df
# Out:
#        loannumber_x  loanamount_x  totaldue_x  termdays_x  loannumber_y  \
# 0                 2       10000.0     13000.0          30            12
# 1                 9       10000.0     13000.0          30            12
# 2                 8       20000.0     23800.0          30            12
# 3                10       20000.0     24500.0          30            12
# 4                11       20000.0     24500.0          30            12
# ...             ...           ...         ...         ...           ...
# 13688             1       10000.0     11500.0          15             2
# 13689             1       10000.0     13000.0          30             2
# 13690             1       10000.0     11500.0          15             2
# 13691             1       10000.0     11500.0          15             2
# 13692             1       10000.0     11500.0          15             2
#
#        loanamount_y  totaldue_y  termdays_y good_bad_flag  \
# 0           30000.0     34500.0          30          Good
# 1           30000.0     34500.0          30          Good
# 2           30000.0     34500.0          30          Good
# 3           30000.0     34500.0          30          Good
# 4           30000.0     34500.0          30          Good
# ...             ...         ...         ...           ...
# 13688       10000.0     11500.0          15          Good
# 13689       10000.0     13000.0          30          Good
# 13690       10000.0     11500.0          15          Good
# 13691       10000.0     13000.0          30          Good
# 13692       10000.0     13000.0          30          Good
#
#                         birthdate bank_account_type  longitude_gps  \
# 0      1972-01-15 00:00:00.000000             Other       3.432010
# 1      1972-01-15 00:00:00.000000             Other       3.432010
# 2      1972-01-15 00:00:00.000000             Other       3.432010
# 3      1972-01-15 00:00:00.000000             Other       3.432010
# 4      1972-01-15 00:00:00.000000             Other       3.432010
# ...                           ...               ...            ...
# 13688  1986-02-20 00:00:00.000000           Savings       5.252457
# 13689  1979-04-18 00:00:00.000000           Savings       7.478858
# 13690  1989-11-19 00:00:00.000000           Savings       3.381677
# 13691  1980-11-12 00:00:00.000000           Savings       6.979660
# 13692  1989-10-24 00:00:00.000000           Savings       7.530892
#
#        latitude_gps bank_name_clients employment_status_clients
# 0          6.433055      Diamond Bank                 Permanent
# 1          6.433055      Diamond Bank                 Permanent
# 2          6.433055      Diamond Bank                 Permanent
# 3          6.433055      Diamond Bank                 Permanent
# 4          6.433055      Diamond Bank                 Permanent
# ...             ...               ...                       ...
# 13688     12.991440               UBA                 Permanent
# 13689      9.055714              FCMB                 Permanent
# 13690      6.455923       Zenith Bank                 Permanent
# 13691      4.879515       Access Bank                Unemployed
# 13692      9.042928           EcoBank                 Permanent
#
# [12310 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12310 entries, 0 to 13692
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loannumber_x               12310 non-null  int64
#  1   loanamount_x               12310 non-null  float64
#  2   totaldue_x                 12310 non-null  float64
#  3   termdays_x                 12310 non-null  int64
#  4   loannumber_y               12310 non-null  int64
#  5   loanamount_y               12310 non-null  float64
#  6   totaldue_y                 12310 non-null  float64
#  7   termdays_y                 12310 non-null  int64
#  8   good_bad_flag              12310 non-null  object
#  9   birthdate                  12310 non-null  object
#  10  bank_account_type          12310 non-null  object
#  11  longitude_gps              12310 non-null  float64
#  12  latitude_gps               12310 non-null  float64
#  13  bank_name_clients          12310 non-null  object
#  14  employment_status_clients  12310 non-null  object
# dtypes: float64(6), int64(4), object(5)
# memory usage: 1.5+ MB

# %%
s=list(df['birthdate'])
df=df.drop('birthdate', axis=1)

# %%
ages=[]
for w in s:
    w=w.split()
    w=w[0]
    w=int(w[:4])
    age=2024-w
    ages.append(age)
df['ages']=ages

# %%
df
# Out:
#        loannumber_x  loanamount_x  totaldue_x  termdays_x  loannumber_y  \
# 0                 2       10000.0     13000.0          30            12
# 1                 9       10000.0     13000.0          30            12
# 2                 8       20000.0     23800.0          30            12
# 3                10       20000.0     24500.0          30            12
# 4                11       20000.0     24500.0          30            12
# ...             ...           ...         ...         ...           ...
# 13688             1       10000.0     11500.0          15             2
# 13689             1       10000.0     13000.0          30             2
# 13690             1       10000.0     11500.0          15             2
# 13691             1       10000.0     11500.0          15             2
# 13692             1       10000.0     11500.0          15             2
#
#        loanamount_y  totaldue_y  termdays_y good_bad_flag bank_account_type  \
# 0           30000.0     34500.0          30          Good             Other
# 1           30000.0     34500.0          30          Good             Other
# 2           30000.0     34500.0          30          Good             Other
# 3           30000.0     34500.0          30          Good             Other
# 4           30000.0     34500.0          30          Good             Other
# ...             ...         ...         ...           ...               ...
# 13688       10000.0     11500.0          15          Good           Savings
# 13689       10000.0     13000.0          30          Good           Savings
# 13690       10000.0     11500.0          15          Good           Savings
# 13691       10000.0     13000.0          30          Good           Savings
# 13692       10000.0     13000.0          30          Good           Savings
#
#        longitude_gps  latitude_gps bank_name_clients  \
# 0           3.432010      6.433055      Diamond Bank
# 1           3.432010      6.433055      Diamond Bank
# 2           3.432010      6.433055      Diamond Bank
# 3           3.432010      6.433055      Diamond Bank
# 4           3.432010      6.433055      Diamond Bank
# ...              ...           ...               ...
# 13688       5.252457     12.991440               UBA
# 13689       7.478858      9.055714              FCMB
# 13690       3.381677      6.455923       Zenith Bank
# 13691       6.979660      4.879515       Access Bank
# 13692       7.530892      9.042928           EcoBank
#
#       employment_status_clients  ages
# 0                     Permanent    52
# 1                     Permanent    52
# 2                     Permanent    52
# 3                     Permanent    52
# 4                     Permanent    52
# ...                         ...   ...
# 13688                 Permanent    38
# 13689                 Permanent    45
# 13690                 Permanent    35
# 13691                Unemployed    44
# 13692                 Permanent    35
#
# [12310 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12310 entries, 0 to 13692
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loannumber_x               12310 non-null  int64
#  1   loanamount_x               12310 non-null  float64
#  2   totaldue_x                 12310 non-null  float64
#  3   termdays_x                 12310 non-null  int64
#  4   loannumber_y               12310 non-null  int64
#  5   loanamount_y               12310 non-null  float64
#  6   totaldue_y                 12310 non-null  float64
#  7   termdays_y                 12310 non-null  int64
#  8   good_bad_flag              12310 non-null  object
#  9   bank_account_type          12310 non-null  object
#  10  longitude_gps              12310 non-null  float64
#  11  latitude_gps               12310 non-null  float64
#  12  bank_name_clients          12310 non-null  object
#  13  employment_status_clients  12310 non-null  object
#  14  ages                       12310 non-null  int64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
df.good_bad_flag.value_counts()
# Out:
# Good    10137
# Bad      2173
# Name: good_bad_flag, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = "good_bad_flag", data = df)
# Out:
# <AxesSubplot:xlabel='good_bad_flag', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='ages',data=df,hue='good_bad_flag')
# Out:
# <AxesSubplot:xlabel='ages', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='loanamount_x',data=df,hue='good_bad_flag')
# Out:
# <AxesSubplot:xlabel='loanamount_x', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='bank_name_clients',data=df,hue='good_bad_flag')
# Out:
# <AxesSubplot:xlabel='bank_name_clients', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='bank_account_type',data=df,hue='good_bad_flag')
# Out:
# <AxesSubplot:xlabel='bank_account_type', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='employment_status_clients',data=df,hue='good_bad_flag')
# Out:
# <AxesSubplot:xlabel='employment_status_clients', ylabel='count'>

# %%
df
# Out:
#        loannumber_x  loanamount_x  totaldue_x  termdays_x  loannumber_y  \
# 0                 2       10000.0     13000.0          30            12
# 1                 9       10000.0     13000.0          30            12
# 2                 8       20000.0     23800.0          30            12
# 3                10       20000.0     24500.0          30            12
# 4                11       20000.0     24500.0          30            12
# ...             ...           ...         ...         ...           ...
# 13688             1       10000.0     11500.0          15             2
# 13689             1       10000.0     13000.0          30             2
# 13690             1       10000.0     11500.0          15             2
# 13691             1       10000.0     11500.0          15             2
# 13692             1       10000.0     11500.0          15             2
#
#        loanamount_y  totaldue_y  termdays_y good_bad_flag bank_account_type  \
# 0           30000.0     34500.0          30          Good             Other
# 1           30000.0     34500.0          30          Good             Other
# 2           30000.0     34500.0          30          Good             Other
# 3           30000.0     34500.0          30          Good             Other
# 4           30000.0     34500.0          30          Good             Other
# ...             ...         ...         ...           ...               ...
# 13688       10000.0     11500.0          15          Good           Savings
# 13689       10000.0     13000.0          30          Good           Savings
# 13690       10000.0     11500.0          15          Good           Savings
# 13691       10000.0     13000.0          30          Good           Savings
# 13692       10000.0     13000.0          30          Good           Savings
#
#        longitude_gps  latitude_gps bank_name_clients  \
# 0           3.432010      6.433055      Diamond Bank
# 1           3.432010      6.433055      Diamond Bank
# 2           3.432010      6.433055      Diamond Bank
# 3           3.432010      6.433055      Diamond Bank
# 4           3.432010      6.433055      Diamond Bank
# ...              ...           ...               ...
# 13688       5.252457     12.991440               UBA
# 13689       7.478858      9.055714              FCMB
# 13690       3.381677      6.455923       Zenith Bank
# 13691       6.979660      4.879515       Access Bank
# 13692       7.530892      9.042928           EcoBank
#
#       employment_status_clients  ages
# 0                     Permanent    52
# 1                     Permanent    52
# 2                     Permanent    52
# 3                     Permanent    52
# 4                     Permanent    52
# ...                         ...   ...
# 13688                 Permanent    38
# 13689                 Permanent    45
# 13690                 Permanent    35
# 13691                Unemployed    44
# 13692                 Permanent    35
#
# [12310 rows x 15 columns]

# %%
obj_columns=['good_bad_flag','bank_account_type','bank_name_clients','employment_status_clients']
le=LabelEncoder()
for x in obj_columns:
    df[x]=le.fit_transform(df[x])
df.head()
# Out:
#    loannumber_x  loanamount_x  totaldue_x  termdays_x  loannumber_y  \
# 0             2       10000.0     13000.0          30            12
# 1             9       10000.0     13000.0          30            12
# 2             8       20000.0     23800.0          30            12
# 3            10       20000.0     24500.0          30            12
# 4            11       20000.0     24500.0          30            12
#
#    loanamount_y  totaldue_y  termdays_y  good_bad_flag  bank_account_type  \
# 0       30000.0     34500.0          30              1                  1
# 1       30000.0     34500.0          30              1                  1
# 2       30000.0     34500.0          30              1                  1
# 3       30000.0     34500.0          30              1                  1
# 4       30000.0     34500.0          30              1                  1
#
#    longitude_gps  latitude_gps  bank_name_clients  employment_status_clients  \
# 0        3.43201      6.433055                  1                          1
# 1        3.43201      6.433055                  1                          1
# 2        3.43201      6.433055                  1                          1
# 3        3.43201      6.433055                  1                          1
# 4        3.43201      6.433055                  1                          1
#
#    ages
# 0    52
# 1    52
# 2    52
# 3    52
# 4    52

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Splitting 1

# %%
x = df.drop('good_bad_flag', axis=1)
y = df['good_bad_flag']

# %%
x
# Out:
#        loannumber_x  loanamount_x  totaldue_x  termdays_x  loannumber_y  \
# 0                 2       10000.0     13000.0          30            12
# 1                 9       10000.0     13000.0          30            12
# 2                 8       20000.0     23800.0          30            12
# 3                10       20000.0     24500.0          30            12
# 4                11       20000.0     24500.0          30            12
# ...             ...           ...         ...         ...           ...
# 13688             1       10000.0     11500.0          15             2
# 13689             1       10000.0     13000.0          30             2
# 13690             1       10000.0     11500.0          15             2
# 13691             1       10000.0     11500.0          15             2
# 13692             1       10000.0     11500.0          15             2
#
#        loanamount_y  totaldue_y  termdays_y  bank_account_type  longitude_gps  \
# 0           30000.0     34500.0          30                  1       3.432010
# 1           30000.0     34500.0          30                  1       3.432010
# 2           30000.0     34500.0          30                  1       3.432010
# 3           30000.0     34500.0          30                  1       3.432010
# 4           30000.0     34500.0          30                  1       3.432010
# ...             ...         ...         ...                ...            ...
# 13688       10000.0     11500.0          15                  2       5.252457
# 13689       10000.0     13000.0          30                  2       7.478858
# 13690       10000.0     11500.0          15                  2       3.381677
# 13691       10000.0     13000.0          30                  2       6.979660
# 13692       10000.0     13000.0          30                  2       7.530892
#
#        latitude_gps  bank_name_clients  employment_status_clients  ages
# 0          6.433055                  1                          1    52
# 1          6.433055                  1                          1    52
# 2          6.433055                  1                          1    52
# 3          6.433055                  1                          1    52
# 4          6.433055                  1                          1    52
# ...             ...                ...                        ...   ...
# 13688     12.991440                 13                          1    38
# 13689      9.055714                  3                          1    45
# 13690      6.455923                 17                          1    35
# 13691      4.879515                  0                          5    44
# 13692      9.042928                  2                          1    35
#
# [12310 rows x 14 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 13688    1
# 13689    1
# 13690    1
# 13691    1
# 13692    1
# Name: good_bad_flag, Length: 12310, dtype: int32

# %% [markdown]
# ## Feature Selection

# %%
rf = RandomForestClassifier()
rf.fit(x,y)
feature_importances = rf.feature_importances_
importance_df = pd.DataFrame({'Feature': x.columns, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
ifs=importance_df['Feature'][:10]
selected_columns = list(ifs)
print(selected_columns)

plt.figure(figsize=(13,7))
plt.bar(ifs, importance_df['Importance'][:10], color='black')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Feature Importances')
plt.xticks(rotation=90)
plt.show()
# Out:
# ['longitude_gps', 'latitude_gps', 'ages', 'loannumber_y', 'bank_name_clients', 'totaldue_y', 'employment_status_clients', 'loanamount_y', 'termdays_y', 'totaldue_x']

# %%
x = df[['longitude_gps', 'latitude_gps', 'ages', 'loannumber_y', 'bank_name_clients', 'totaldue_y', 'loanamount_y', 'employment_status_clients', 'termdays_y', 'totaldue_x']]

# %%
x
# Out:
#        longitude_gps  latitude_gps  ages  loannumber_y  bank_name_clients  \
# 0           3.432010      6.433055    52            12                  1
# 1           3.432010      6.433055    52            12                  1
# 2           3.432010      6.433055    52            12                  1
# 3           3.432010      6.433055    52            12                  1
# 4           3.432010      6.433055    52            12                  1
# ...              ...           ...   ...           ...                ...
# 13688       5.252457     12.991440    38             2                 13
# 13689       7.478858      9.055714    45             2                  3
# 13690       3.381677      6.455923    35             2                 17
# 13691       6.979660      4.879515    44             2                  0
# 13692       7.530892      9.042928    35             2                  2
#
#        totaldue_y  loanamount_y  employment_status_clients  termdays_y  \
# 0         34500.0       30000.0                          1          30
# 1         34500.0       30000.0                          1          30
# 2         34500.0       30000.0                          1          30
# 3         34500.0       30000.0                          1          30
# 4         34500.0       30000.0                          1          30
# ...           ...           ...                        ...         ...
# 13688     11500.0       10000.0                          1          15
# 13689     13000.0       10000.0                          1          30
# 13690     11500.0       10000.0                          1          15
# 13691     13000.0       10000.0                          5          30
# 13692     13000.0       10000.0                          1          30
#
#        totaldue_x
# 0         13000.0
# 1         13000.0
# 2         23800.0
# 3         24500.0
# 4         24500.0
# ...           ...
# 13688     11500.0
# 13689     13000.0
# 13690     11500.0
# 13691     11500.0
# 13692     11500.0
#
# [12310 rows x 10 columns]

# %%
sc=StandardScaler()
x = sc.fit_transform(x)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x, y = smote.fit_resample(x, y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
scm_model = SVC()
scm_model.fit(x_train, y_train)
scm_pred = scm_model.predict(x_test)
print(classification_report(scm_pred, y_test))
print('precision score:',precision_score(y_test,scm_pred))
print('Recall score:',recall_score(y_test,scm_pred))
print('F1 score:',f1_score(y_test,scm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75      1163
#            1       0.65      0.78      0.71       865
#
#     accuracy                           0.73      2028
#    macro avg       0.73      0.74      0.73      2028
# weighted avg       0.74      0.73      0.73      2028
#
# precision score: 0.7826589595375723
# Recall score: 0.6541062801932367
# F1 score: 0.7126315789473685

# %%
plt.figure(figsize=(10,6))
fx=sns.heatmap(confusion_matrix(y_test, scm_pred),annot=True,fmt='.0f',cmap='GnBu')
fx.set_xlabel('PREDICTED VALUES')
fx.set_ylabel('ACTUAL VALUES')
plt.show()

# %%
lg_model = LogisticRegression()
lg_model.fit(x_train, y_train)
lg_pred = lg_model.predict(x_test)
print(classification_report(lg_pred, y_test))
print('precision score:',precision_score(y_test,lg_pred))
print('Recall score:',recall_score(y_test,lg_pred))
print('F1 score:',f1_score(y_test,lg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.56      0.60      1161
#            1       0.50      0.60      0.55       867
#
#     accuracy                           0.58      2028
#    macro avg       0.58      0.58      0.58      2028
# weighted avg       0.59      0.58      0.58      2028
#
# precision score: 0.6020761245674741
# Recall score: 0.5043478260869565
# F1 score: 0.5488958990536277

# %%
plt.figure(figsize=(10,6))
fx=sns.heatmap(confusion_matrix(y_test, lg_pred),annot=True,fmt='.0f',cmap='GnBu')
fx.set_xlabel('PREDICTED VALUES')
fx.set_ylabel('ACTUAL VALUES')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(x_train, y_train)
rf_pred = rf_model.predict(x_test)
print(classification_report(rf_pred, y_test))
print('precision score:',precision_score(y_test,rf_pred))
print('Recall score:',recall_score(y_test,rf_pred))
print('F1 score:',f1_score(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       983
#            1       0.99      0.98      0.98      1045
#
#     accuracy                           0.98      2028
#    macro avg       0.98      0.98      0.98      2028
# weighted avg       0.98      0.98      0.98      2028
#
# precision score: 0.9799043062200957
# Recall score: 0.9893719806763285
# F1 score: 0.9846153846153846

# %%
plt.figure(figsize=(10,6))
fx=sns.heatmap(confusion_matrix(y_test, rf_pred),annot=True,fmt='.0f',cmap='GnBu')
fx.set_xlabel('PREDICTED VALUES')
fx.set_ylabel('ACTUAL VALUES')
plt.show()

# %%
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier(hidden_layer_sizes=(128,64))
mlp.fit(x_train, y_train)
mlp_pred= mlp.predict(x_test)
print(classification_report(mlp_pred, y_test))
print('precision score:',precision_score(y_test,mlp_pred))
print('Recall score:',recall_score(y_test,mlp_pred))
print('F1 score:',f1_score(y_test,mlp_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       980
#            1       0.95      0.94      0.94      1048
#
#     accuracy                           0.94      2028
#    macro avg       0.94      0.94      0.94      2028
# weighted avg       0.94      0.94      0.94      2028
#
# precision score: 0.9389312977099237
# Recall score: 0.9507246376811594
# F1 score: 0.9447911665866539

# %%
plt.figure(figsize=(10,6))
fx=sns.heatmap(confusion_matrix(y_test, mlp_pred),annot=True,fmt='.0f',cmap='GnBu')
fx.set_xlabel('PREDICTED VALUES')
fx.set_ylabel('ACTUAL VALUES')
plt.show()

# %%
model=Sequential()
model.add(Dense(124,activation='relu',input_shape=(10,)))
model.add(Dense(64,activation='relu'))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 124)               1364
#
#  dense_1 (Dense)             (None, 64)                8000
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 21,909
# Trainable params: 21,909
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
his=model.fit(x_train,y_train,epochs=100,batch_size=32,validation_data=(x_test, y_test))
ann_pred=model.predict(x_test)
ann_pred=(ann_pred>=0.5).astype(int)
ann_pred
# Out:
# Epoch 1/100
# 571/571 [==============================] - 8s 6ms/step - loss: 0.6464 - accuracy: 0.6167 - val_loss: 0.5951 - val_accuracy: 0.6736
# Epoch 2/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.5184 - accuracy: 0.7304 - val_loss: 0.4663 - val_accuracy: 0.7608
# Epoch 3/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.3959 - accuracy: 0.8085 - val_loss: 0.3486 - val_accuracy: 0.8156
# Epoch 4/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.3363 - accuracy: 0.8384 - val_loss: 0.3694 - val_accuracy: 0.8156
# Epoch 5/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2837 - accuracy: 0.8648 - val_loss: 0.2586 - val_accuracy: 0.8708
# Epoch 6/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2594 - accuracy: 0.8742 - val_loss: 0.2860 - val_accuracy: 0.8629
# Epoch 7/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2452 - accuracy: 0.8817 - val_loss: 0.2424 - val_accuracy: 0.8787
# Epoch 8/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2210 - accuracy: 0.8934 - val_loss: 0.2267 - val_accuracy: 0.8881
# Epoch 9/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2170 - accuracy: 0.8966 - val_loss: 0.2478 - val_accuracy: 0.8856
# Epoch 10/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.2026 - accuracy: 0.9052 - val_loss: 0.2267 - val_accuracy: 0.8792
# Epoch 11/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1972 - accuracy: 0.9049 - val_loss: 0.2271 - val_accuracy: 0.8836
# Epoch 12/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1968 - accuracy: 0.9093 - val_loss: 0.2029 - val_accuracy: 0.8955
# Epoch 13/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1841 - accuracy: 0.9119 - val_loss: 0.2196 - val_accuracy: 0.8950
# Epoch 14/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1735 - accuracy: 0.9173 - val_loss: 0.2092 - val_accuracy: 0.8984
# Epoch 15/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1642 - accuracy: 0.9199 - val_loss: 0.2455 - val_accuracy: 0.8999
# Epoch 16/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1712 - accuracy: 0.9195 - val_loss: 0.1902 - val_accuracy: 0.9098
# Epoch 17/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1551 - accuracy: 0.9245 - val_loss: 0.1854 - val_accuracy: 0.9093
# Epoch 18/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1598 - accuracy: 0.9251 - val_loss: 0.1667 - val_accuracy: 0.9216
# Epoch 19/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1559 - accuracy: 0.9283 - val_loss: 0.1840 - val_accuracy: 0.9103
# Epoch 20/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1496 - accuracy: 0.9309 - val_loss: 0.1701 - val_accuracy: 0.9172
# Epoch 21/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1471 - accuracy: 0.9305 - val_loss: 0.2267 - val_accuracy: 0.9078
# Epoch 22/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1418 - accuracy: 0.9337 - val_loss: 0.1628 - val_accuracy: 0.9206
# Epoch 23/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1377 - accuracy: 0.9363 - val_loss: 0.1536 - val_accuracy: 0.9255
# Epoch 24/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1310 - accuracy: 0.9370 - val_loss: 0.1770 - val_accuracy: 0.9152
# Epoch 25/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1419 - accuracy: 0.9340 - val_loss: 0.1480 - val_accuracy: 0.9300
# Epoch 26/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1271 - accuracy: 0.9401 - val_loss: 0.1308 - val_accuracy: 0.9290
# Epoch 27/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1211 - accuracy: 0.9399 - val_loss: 0.1463 - val_accuracy: 0.9285
# Epoch 28/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1292 - accuracy: 0.9377 - val_loss: 0.1526 - val_accuracy: 0.9310
# Epoch 29/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1191 - accuracy: 0.9428 - val_loss: 0.1240 - val_accuracy: 0.9334
# Epoch 30/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1218 - accuracy: 0.9431 - val_loss: 0.1525 - val_accuracy: 0.9275
# Epoch 31/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1184 - accuracy: 0.9448 - val_loss: 0.1289 - val_accuracy: 0.9315
# Epoch 32/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1144 - accuracy: 0.9460 - val_loss: 0.1356 - val_accuracy: 0.9329
# Epoch 33/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1102 - accuracy: 0.9469 - val_loss: 0.1884 - val_accuracy: 0.9270
# Epoch 34/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1205 - accuracy: 0.9451 - val_loss: 0.1367 - val_accuracy: 0.9255
# Epoch 35/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1082 - accuracy: 0.9474 - val_loss: 0.1306 - val_accuracy: 0.9354
# Epoch 36/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1098 - accuracy: 0.9474 - val_loss: 0.1392 - val_accuracy: 0.9364
# Epoch 37/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1124 - accuracy: 0.9467 - val_loss: 0.1290 - val_accuracy: 0.9393
# Epoch 38/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1055 - accuracy: 0.9516 - val_loss: 0.1282 - val_accuracy: 0.9389
# Epoch 39/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1136 - accuracy: 0.9479 - val_loss: 0.1172 - val_accuracy: 0.9433
# Epoch 40/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1032 - accuracy: 0.9514 - val_loss: 0.1581 - val_accuracy: 0.9285
# Epoch 41/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1032 - accuracy: 0.9517 - val_loss: 0.1328 - val_accuracy: 0.9418
# Epoch 42/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1094 - accuracy: 0.9501 - val_loss: 0.1317 - val_accuracy: 0.9389
# Epoch 43/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0940 - accuracy: 0.9557 - val_loss: 0.1251 - val_accuracy: 0.9438
# Epoch 44/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1031 - accuracy: 0.9518 - val_loss: 0.1278 - val_accuracy: 0.9423
# Epoch 45/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0993 - accuracy: 0.9546 - val_loss: 0.1581 - val_accuracy: 0.9334
# Epoch 46/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0969 - accuracy: 0.9559 - val_loss: 0.1084 - val_accuracy: 0.9497
# Epoch 47/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0978 - accuracy: 0.9545 - val_loss: 0.1462 - val_accuracy: 0.9320
# Epoch 48/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1013 - accuracy: 0.9552 - val_loss: 0.1206 - val_accuracy: 0.9492
# Epoch 49/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0969 - accuracy: 0.9559 - val_loss: 0.1110 - val_accuracy: 0.9497
# Epoch 50/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0876 - accuracy: 0.9593 - val_loss: 0.1162 - val_accuracy: 0.9487
# Epoch 51/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.1017 - accuracy: 0.9558 - val_loss: 0.1288 - val_accuracy: 0.9448
# Epoch 52/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0890 - accuracy: 0.9594 - val_loss: 0.1330 - val_accuracy: 0.9379
# Epoch 53/100
# 571/571 [==============================] - 3s 4ms/step - loss: 0.0948 - accuracy: 0.9580 - val_loss: 0.1085 - val_accuracy: 0.9512
# Epoch 54/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0820 - accuracy: 0.9621 - val_loss: 0.1109 - val_accuracy: 0.9556
# Epoch 55/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0863 - accuracy: 0.9607 - val_loss: 0.1292 - val_accuracy: 0.9497
# Epoch 56/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0917 - accuracy: 0.9596 - val_loss: 0.1060 - val_accuracy: 0.9576
# Epoch 57/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0960 - accuracy: 0.9591 - val_loss: 0.1149 - val_accuracy: 0.9487
# Epoch 58/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0859 - accuracy: 0.9618 - val_loss: 0.1145 - val_accuracy: 0.9482
# Epoch 59/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0871 - accuracy: 0.9617 - val_loss: 0.1033 - val_accuracy: 0.9536
# Epoch 60/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0826 - accuracy: 0.9652 - val_loss: 0.0974 - val_accuracy: 0.9576
# Epoch 61/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0922 - accuracy: 0.9608 - val_loss: 0.1643 - val_accuracy: 0.9403
# Epoch 62/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0854 - accuracy: 0.9627 - val_loss: 0.1010 - val_accuracy: 0.9586
# Epoch 63/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0709 - accuracy: 0.9684 - val_loss: 0.1127 - val_accuracy: 0.9541
# Epoch 64/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0940 - accuracy: 0.9623 - val_loss: 0.1201 - val_accuracy: 0.9546
# Epoch 65/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0847 - accuracy: 0.9644 - val_loss: 0.1012 - val_accuracy: 0.9561
# Epoch 66/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0745 - accuracy: 0.9673 - val_loss: 0.1268 - val_accuracy: 0.9541
# Epoch 67/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0866 - accuracy: 0.9632 - val_loss: 0.1080 - val_accuracy: 0.9551
# Epoch 68/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0763 - accuracy: 0.9666 - val_loss: 0.1069 - val_accuracy: 0.9546
# Epoch 69/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0711 - accuracy: 0.9694 - val_loss: 0.0953 - val_accuracy: 0.9596
# Epoch 70/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0808 - accuracy: 0.9653 - val_loss: 0.1088 - val_accuracy: 0.9522
# Epoch 71/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0795 - accuracy: 0.9649 - val_loss: 0.1103 - val_accuracy: 0.9581
# Epoch 72/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0720 - accuracy: 0.9688 - val_loss: 0.1031 - val_accuracy: 0.9561
# Epoch 73/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0831 - accuracy: 0.9662 - val_loss: 0.1035 - val_accuracy: 0.9546
# Epoch 74/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0764 - accuracy: 0.9679 - val_loss: 0.0956 - val_accuracy: 0.9635
# Epoch 75/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0805 - accuracy: 0.9648 - val_loss: 0.1104 - val_accuracy: 0.9546
# Epoch 76/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0741 - accuracy: 0.9683 - val_loss: 0.0938 - val_accuracy: 0.9655
# Epoch 77/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0632 - accuracy: 0.9727 - val_loss: 0.1168 - val_accuracy: 0.9581
# Epoch 78/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0754 - accuracy: 0.9695 - val_loss: 0.1033 - val_accuracy: 0.9561
# Epoch 79/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0741 - accuracy: 0.9682 - val_loss: 0.1089 - val_accuracy: 0.9591
# Epoch 80/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0719 - accuracy: 0.9716 - val_loss: 0.1077 - val_accuracy: 0.9596
# Epoch 81/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0685 - accuracy: 0.9710 - val_loss: 0.1068 - val_accuracy: 0.9601
# Epoch 82/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0764 - accuracy: 0.9695 - val_loss: 0.1052 - val_accuracy: 0.9527
# Epoch 83/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0669 - accuracy: 0.9713 - val_loss: 0.1014 - val_accuracy: 0.9601
# Epoch 84/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0787 - accuracy: 0.9689 - val_loss: 0.1155 - val_accuracy: 0.9527
# Epoch 85/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0662 - accuracy: 0.9720 - val_loss: 0.0944 - val_accuracy: 0.9660
# Epoch 86/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0637 - accuracy: 0.9725 - val_loss: 0.1029 - val_accuracy: 0.9596
# Epoch 87/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0698 - accuracy: 0.9703 - val_loss: 0.1167 - val_accuracy: 0.9625
# Epoch 88/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0724 - accuracy: 0.9711 - val_loss: 0.1310 - val_accuracy: 0.9571
# Epoch 89/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0739 - accuracy: 0.9706 - val_loss: 0.0997 - val_accuracy: 0.9601
# Epoch 90/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0661 - accuracy: 0.9710 - val_loss: 0.0846 - val_accuracy: 0.9684
# Epoch 91/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0643 - accuracy: 0.9744 - val_loss: 0.0965 - val_accuracy: 0.9630
# Epoch 92/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0680 - accuracy: 0.9718 - val_loss: 0.0898 - val_accuracy: 0.9645
# Epoch 93/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0592 - accuracy: 0.9741 - val_loss: 0.0811 - val_accuracy: 0.9694
# Epoch 94/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0620 - accuracy: 0.9730 - val_loss: 0.0908 - val_accuracy: 0.9625
# Epoch 95/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0864 - accuracy: 0.9683 - val_loss: 0.0903 - val_accuracy: 0.9630
# Epoch 96/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0631 - accuracy: 0.9740 - val_loss: 0.1062 - val_accuracy: 0.9581
# Epoch 97/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0589 - accuracy: 0.9751 - val_loss: 0.0831 - val_accuracy: 0.9684
# Epoch 98/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0651 - accuracy: 0.9730 - val_loss: 0.1175 - val_accuracy: 0.9630
# Epoch 99/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0665 - accuracy: 0.9722 - val_loss: 0.0899 - val_accuracy: 0.9620
# Epoch 100/100
# 571/571 [==============================] - 3s 5ms/step - loss: 0.0619 - accuracy: 0.9749 - val_loss: 0.1024 - val_accuracy: 0.9606
# 64/64 [==============================] - 1s 2ms/step
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [1],
#        [0]])

# %%
plt.figure(figsize=(10,5))
plt.plot(his.history['loss'])
plt.plot(his.history['val_loss'])
plt.legend(['train','test'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('Epochs')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(his.history['accuracy'])
plt.plot(his.history['val_accuracy'])
plt.legend(['train','test'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.show()

# %%
print(classification_report(ann_pred, y_test))
print('precision score:',precision_score(y_test,ann_pred))
print('Recall score:',recall_score(y_test,ann_pred))
print('F1 score:',f1_score(y_test,ann_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1003
#            1       0.96      0.97      0.96      1025
#
#     accuracy                           0.96      2028
#    macro avg       0.96      0.96      0.96      2028
# weighted avg       0.96      0.96      0.96      2028
#
# precision score: 0.9658536585365853
# Recall score: 0.9565217391304348
# F1 score: 0.9611650485436893

# %%
plt.figure(figsize=(10,6))
fx=sns.heatmap(confusion_matrix(y_test, ann_pred),annot=True,fmt='.0f',cmap='GnBu')
fx.set_xlabel('PREDICTED VALUES')
fx.set_ylabel('ACTUAL VALUES')
plt.show()

# %%
from sklearn.ensemble import StackingClassifier

stacking_clf = StackingClassifier(estimators=[('rf', rf_model), ('nn', mlp)], final_estimator=mlp)
stacking_clf.fit(x_train, y_train)
stacking_pred = stacking_clf.predict(x_test)
print(classification_report(rf_pred, y_test))
print('precision score:',precision_score(y_test,stacking_pred))
print('Recall score:',recall_score(y_test,stacking_pred))
print('F1 score:',f1_score(y_test,stacking_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       983
#            1       0.99      0.98      0.98      1045
#
#     accuracy                           0.98      2028
#    macro avg       0.98      0.98      0.98      2028
# weighted avg       0.98      0.98      0.98      2028
#
# precision score: 0.9799809342230696
# Recall score: 0.9932367149758454
# F1 score: 0.9865642994241843

# %%
plt.figure(figsize=(10,6))
fx=sns.heatmap(confusion_matrix(y_test, stacking_pred),annot=True,fmt='.0f',cmap='GnBu')
fx.set_xlabel('PREDICTED VALUES')
fx.set_ylabel('ACTUAL VALUES')
plt.show()

# %%
import pickle
with open('model.pkl', 'wb') as f:
    pickle.dump(stacking_clf,f)

# %%
# from google.colab import files
# files.upload()

# %%
# df1 = pd.read_csv("data/test3.csv")
# df2= pd.read_csv("data/test1.xls")
# df3 = pd.read_csv("data/test2.xls")
# df=pd.merge(df1,df2, how='inner',on='customerid')
# df=pd.merge(df,df3, how='inner',on='customerid')
# df=df.drop(['bank_branch_clients','level_of_education_clients','referredby_y','referredby_x','bank_branch_clients'],axis=1)
# df=df.dropna()
# obj_columns=['bank_account_type','bank_name_clients','employment_status_clients']
# le=LabelEncoder()
# for x in obj_columns:
#     df[x]=le.fit_transform(df[x])
# s=list(df['birthdate'])
# df=df.drop('birthdate', axis=1)
# ages=[]
# for w in s:
#     w=w.split()
#     w=w[0]
#     w=int(w[:4])
#     age=2024-w
#     ages.append(age)
# df['ages']=ages
# test_data = df[['longitude_gps', 'latitude_gps', 'ages', 'loannumber_y', 'bank_name_clients', 'totaldue_y', 'loanamount_y', 'employment_status_clients', 'termdays_y', 'totaldue_x']]

# %%
# test_data
# Out:
#       longitude_gps  latitude_gps  ages  loannumber_y  bank_name_clients  \
# 0          3.227945      6.586668    43             6                 11
# 1          3.227945      6.586668    43             6                 11
# 2          3.227945      6.586668    43             6                 11
# 3          3.227945      6.586668    43             6                 11
# 4          3.227945      6.586668    43             6                 11
# ...             ...           ...   ...           ...                ...
# 1600       4.612674      8.481447    40             2                  2
# 1601       3.280841      6.596140    44             2                  6
# 1602       3.330235      6.721242    29             2                  6
# 1603       3.658701      6.836310    38             2                  0
# 1604       6.729505      6.202439    31             2                 15
#
#       totaldue_y  loanamount_y  employment_status_clients  termdays_y  \
# 0        24500.0         20000                          0          30
# 1        24500.0         20000                          0          30
# 2        24500.0         20000                          0          30
# 3        24500.0         20000                          0          30
# 4        24500.0         20000                          0          30
# ...          ...           ...                        ...         ...
# 1600     13000.0         10000                          0          30
# 1601     13000.0         10000                          0          30
# 1602     11500.0         10000                          0          15
# 1603     11500.0         10000                          0          15
# 1604     13000.0         10000                          0          30
#
#       totaldue_x
# 0        13000.0
# 1        11500.0
# 2        23800.0
# 3        18375.0
# 4        13000.0
# ...          ...
# 1600     11500.0
# 1601     13000.0
# 1602     11500.0
# 1603     11500.0
# 1604     13000.0
#
# [1459 rows x 10 columns]

# %%
# import pickle
# load_model = pickle.load(open('model.pkl', 'rb'))

# %%
# load_model
# Out:
# StackingClassifier(estimators=[('rf', RandomForestClassifier()),
#                                ('nn',
#                                 MLPClassifier(hidden_layer_sizes=(128, 64)))],
#                    final_estimator=MLPClassifier(hidden_layer_sizes=(128, 64)))

# %%
# y_pred = load_model.predict(test_data)
